# %%
import pandas as pd
import numpy as np

# %%
df_paromunicipio2024 = pd.read_csv(
    './Paro_por_municipios_2014_csv.csv',
    encoding='ISO-8859-1',
    sep=';',
    header=1
)

df_paromunicipio2024.head()
# Out:
#    Código mes             mes  Código de CA Comunidad Autónoma  \
# 0       201401  Enero de 2014             1          Andalucía
# 1       201401  Enero de 2014             1          Andalucía
# 2       201401  Enero de 2014             1          Andalucía
# 3       201401  Enero de 2014             1          Andalucía
# 4       201401  Enero de 2014             1          Andalucía
#
#    Codigo Provincia Provincia  Codigo Municipio  Municipio  \
# 0                 4   Almería              4001       Abla
# 1                 4   Almería              4002   Abrucena
# 2                 4   Almería              4003       Adra
# 3                 4   Almería              4004  Albánchez
# 4                 4   Almería              4005  Alboloduy
#
#    total Paro Registrado  Paro hombre edad < 25  Paro hombre edad 25 -45   \
# 0                    130                      6                        35
# 1                     77                      5                        21
# ...

# %%
df_paromunicipio2024 = pd.read_csv(
    './Paro_por_municipios_2019_csv.csv',
    encoding='ISO-8859-1',
    sep=';',
    header=1
)

df_paromunicipio2024.head()
# Out:
#    Código mes             mes  Código de CA Comunidad Autónoma  \
# 0       201901  Enero de 2019             1          Andalucía
# 1       201901  Enero de 2019             1          Andalucía
# 2       201901  Enero de 2019             1          Andalucía
# 3       201901  Enero de 2019             1          Andalucía
# 4       201901  Enero de 2019             1          Andalucía
#
#    Codigo Provincia Provincia  Codigo Municipio  Municipio  \
# 0                 4   Almería              4001       Abla
# 1                 4   Almería              4002   Abrucena
# 2                 4   Almería              4003       Adra
# 3                 4   Almería              4004  Albánchez
# 4                 4   Almería              4005  Alboloduy
#
#    total Paro Registrado  Paro hombre edad < 25  Paro hombre edad 25 -45   \
# 0                     77                      4                        15
# 1                     62                      5                         9
# ...

# %%
df_paromunicipio2024 = pd.read_csv(
    './Paro_por_municipios_2024_csv.csv',
    encoding='ISO-8859-1',
    sep=';',
    header=1
)

df_paromunicipio2024.head()
# Out:
#    Código mes             mes  Código de CA Comunidad Autónoma  \
# 0       202401  Enero de 2024             1          Andalucía
# 1       202401  Enero de 2024             1          Andalucía
# 2       202401  Enero de 2024             1          Andalucía
# 3       202401  Enero de 2024             1          Andalucía
# 4       202401  Enero de 2024             1          Andalucía
#
#    Codigo Provincia Provincia  Codigo Municipio  Municipio  \
# 0                 4   Almería              4001       Abla
# 1                 4   Almería              4002   Abrucena
# 2                 4   Almería              4003       Adra
# 3                 4   Almería              4004  Albánchez
# 4                 4   Almería              4005  Alboloduy
#
#   total Paro Registrado Paro hombre edad < 25 Paro hombre edad 25 -45   \
# 0                    80                    <5                       10
# 1                    53                    <5                        7
# ...
