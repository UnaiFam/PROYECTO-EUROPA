# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url1 = "https://sede.agenciatributaria.gob.es/AEAT/Contenidos_Comunes/La_Agencia_Tributaria/Estadisticas/Publicaciones/sites/irpfmunicipios/2022/jrubik7dee196ae088a75d2d7a295902b8c75056a9ed80.html"

response = requests.get(url)
response.encoding = 'utf-8'  
soup = BeautifulSoup(response.text, 'html.parser')

tables = soup.find_all('table')

df = pd.read_html(str(tables[0]), decimal=",", thousands=".")[0]

df.to_csv("datos_irpf_provincia.csv_2022", index=False)

print(df.shape)
df.head(50)
# Out:
# (68, 10)
# C:\Users\Jon\AppData\Local\Temp\ipykernel_26792\1200132715.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(tables[0]), decimal=",", thousands=".")[0]
#                  Unnamed: 0  Número de declaraciones  Renta bruta media  \
# 0                     Total                 22898072              30400
# 1                 Andalucía                  4092833              25203
# 2                   Almería                   370379              22508
# 3                     Cádiz                   562798              25902
# 4                   Córdoba                   386797              23546
# 5                   Granada                   453968              25024
# 6                    Huelva                   268057              22377
# 7                      Jaén                   323032              21493
# ...

# %%
url2 = "https://sede.agenciatributaria.gob.es/AEAT/Contenidos_Comunes/La_Agencia_Tributaria/Estadisticas/Publicaciones/sites/irpfmunicipios/2019/jrubikf75972228ea46b0ae33eab3856fdab1bf0228bd6f.html"

response = requests.get(url)
response.encoding = 'utf-8'  
soup = BeautifulSoup(response.text, 'html.parser')

tables = soup.find_all('table')

df = pd.read_html(str(tables[0]), decimal=",", thousands=".")[0]

df.to_csv("datos_irpf_provincia_2019.csv", index=False)

print(df.shape)
df.head(50)
# Out:
# (68, 10)
# C:\Users\Jon\AppData\Local\Temp\ipykernel_26792\716885130.py:9: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(tables[0]), decimal=",", thousands=".")[0]
#                  Unnamed: 0  Número de declaraciones  Renta bruta media  \
# 0                     Total                 22898072              30400
# 1                 Andalucía                  4092833              25203
# 2                   Almería                   370379              22508
# 3                     Cádiz                   562798              25902
# 4                   Córdoba                   386797              23546
# 5                   Granada                   453968              25024
# 6                    Huelva                   268057              22377
# 7                      Jaén                   323032              21493
# ...

# %%
url3 = "https://sede.agenciatributaria.gob.es/AEAT/Contenidos_Comunes/La_Agencia_Tributaria/Estadisticas/Publicaciones/sites/irpfmunicipios/2016/jrubik3f9f09f705d8c4130e1303e412a2dd0af62da913.html"

response = requests.get(url)
response.encoding = 'utf-8'  
soup = BeautifulSoup(response.text, 'html.parser')

tables = soup.find_all('table')

df = pd.read_html(str(tables[0]), decimal=",", thousands=".")[0]

df.to_csv("datos_irpf_provincia_2016.csv", index=False)

print(df.shape)
df.head(50)
# Out:
# (68, 10)
# C:\Users\Jon\AppData\Local\Temp\ipykernel_26792\386893499.py:9: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(tables[0]), decimal=",", thousands=".")[0]
#                  Unnamed: 0  Número de declaraciones  Renta bruta media  \
# 0                     Total                 22898072              30400
# 1                 Andalucía                  4092833              25203
# 2                   Almería                   370379              22508
# 3                     Cádiz                   562798              25902
# 4                   Córdoba                   386797              23546
# 5                   Granada                   453968              25024
# 6                    Huelva                   268057              22377
# 7                      Jaén                   323032              21493
# ...
