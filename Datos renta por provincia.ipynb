# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url1 = "https://sede.agenciatributaria.gob.es/AEAT/Contenidos_Comunes/La_Agencia_Tributaria/Estadisticas/Publicaciones/sites/irpfmunicipios/2022/jrubik7dee196ae088a75d2d7a295902b8c75056a9ed80.html"

response = requests.get(url1)
response.encoding = 'utf-8'  
soup = BeautifulSoup(response.text, 'html.parser')

tables = soup.find_all('table')

df1 = pd.read_html(str(tables[0]), decimal=",", thousands=".")[0]
df1 = df1.rename(columns={"Unnamed: 0": "Provincia"})




print(df1.shape)
df1.head(70)
# Out:
# (68, 10)
# C:\Users\Jon\AppData\Local\Temp\ipykernel_21880\2089857388.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df1 = pd.read_html(str(tables[0]), decimal=",", thousands=".")[0]
#         Provincia  Número de declaraciones  Renta bruta media  \
# 0           Total                 22898072              30400
# 1       Andalucía                  4092833              25203
# 2         Almería                   370379              22508
# 3           Cádiz                   562798              25902
# 4         Córdoba                   386797              23546
# ..            ...                      ...                ...
# 63          Ceuta                    35157              31453
# 64        Melilla                    35796              31026
# 65        Melilla                    35796              31026
# ...

# %%
dict_provincia = {
    "Araba/Álava": 1, "Albacete": 2, "Alicante/Alacant": 3, "Almería": 4, "Ávila": 5,
    "Badajoz": 6, "Balears, Illes": 7, "Barcelona": 8, "Burgos": 9, "Cáceres": 10,
    "Cádiz": 11, "Castellón/Castelló": 12, "Ciudad Real": 13, "Córdoba": 14,
    "Coruña, A": 15, "Cuenca": 16, "Girona": 17, "Granada": 18, "Guadalajara": 19,
    "Gipuzkoa": 20, "Huelva": 21, "Huesca": 22, "Jaén": 23, "León": 24, "Lleida": 25,
    "Rioja, La": 26, "Lugo": 27, "Madrid": 28, "Málaga": 29, "Murcia": 30, "Navarra": 31,
    "Ourense": 32, "Asturias": 33, "Palencia": 34, "Palmas, Las": 35, "Pontevedra": 36,
    "Salamanca": 37, "Santa Cruz de Tenerife": 38, "Cantabria": 39, "Segovia": 40,
    "Sevilla": 41, "Soria": 42, "Tarragona": 43, "Teruel": 44, "Toledo": 45,
    "Valencia/València": 46, "Valladolid": 47, "Bizkaia": 48, "Zamora": 49,
    "Zaragoza": 50, "Ceuta": 51, "Melilla": 52
}

df1['id_provincia'] = df1['Provincia'].apply(lambda x : dict_provincia[x] if x in dict_provincia else x)
df1 = df1[df1['Provincia'] != df1[df1.columns[-1]]]
df1 = df1.reset_index(drop=True)
df1 = df1.drop_duplicates(subset="Provincia", keep="first")

df1.head(70)
# Out:
#                  Provincia  Número de declaraciones  Renta bruta media  \
# 0                  Almería                   370379              22508
# 1                    Cádiz                   562798              25902
# 2                  Córdoba                   386797              23546
# 3                  Granada                   453968              25024
# 4                   Huelva                   268057              22377
# 5                     Jaén                   323032              21493
# 6                   Málaga                   791650              27131
# 7                  Sevilla                   936152              27078
# 8                   Huesca                   121558              27781
# 9                   Teruel                    72031              25682
# 10                Zaragoza                   553870              29934
# 11                Asturias                   544015              29498
# ...

# %%
url2 = "https://sede.agenciatributaria.gob.es/AEAT/Contenidos_Comunes/La_Agencia_Tributaria/Estadisticas/Publicaciones/sites/irpfmunicipios/2019/jrubikf75972228ea46b0ae33eab3856fdab1bf0228bd6f.html"

response = requests.get(url2)
response.encoding = 'utf-8'  
soup = BeautifulSoup(response.text, 'html.parser')

tables = soup.find_all('table')

df2 = pd.read_html(str(tables[0]), decimal=",", thousands=".")[0]
df2 = df2.rename(columns={"Unnamed: 0": "Provincia"})
periodo = 2019
df2['Año'] = periodo

print(df2.shape)
df2.head(70)
# Out:
# (68, 11)
# C:\Users\Jon\AppData\Local\Temp\ipykernel_21880\3850065917.py:9: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df2 = pd.read_html(str(tables[0]), decimal=",", thousands=".")[0]
#         Provincia  Número de declaraciones  Renta bruta media  \
# 0           Total                 21028886              28384
# 1       Andalucía                  3642683              23510
# 2         Almería                   324413              21399
# 3           Cádiz                   495879              24497
# 4         Córdoba                   351445              21879
# ..            ...                      ...                ...
# 63          Ceuta                    31336              31504
# 64        Melilla                    32015              30175
# 65        Melilla                    32015              30175
# ...

# %%
dict_provincia = {
    "Araba/Álava": 1, "Albacete": 2, "Alicante/Alacant": 3, "Almería": 4, "Ávila": 5,
    "Badajoz": 6, "Balears, Illes": 7, "Barcelona": 8, "Burgos": 9, "Cáceres": 10,
    "Cádiz": 11, "Castellón/Castelló": 12, "Ciudad Real": 13, "Córdoba": 14,
    "Coruña, A": 15, "Cuenca": 16, "Girona": 17, "Granada": 18, "Guadalajara": 19,
    "Gipuzkoa": 20, "Huelva": 21, "Huesca": 22, "Jaén": 23, "León": 24, "Lleida": 25,
    "Rioja, La": 26, "Lugo": 27, "Madrid": 28, "Málaga": 29, "Murcia": 30, "Navarra": 31,
    "Ourense": 32, "Asturias": 33, "Palencia": 34, "Palmas, Las": 35, "Pontevedra": 36,
    "Salamanca": 37, "Santa Cruz de Tenerife": 38, "Cantabria": 39, "Segovia": 40,
    "Sevilla": 41, "Soria": 42, "Tarragona": 43, "Teruel": 44, "Toledo": 45,
    "Valencia/València": 46, "Valladolid": 47, "Bizkaia": 48, "Zamora": 49,
    "Zaragoza": 50, "Ceuta": 51, "Melilla": 52
}

df2['id_provincia'] = df2['Provincia'].apply(lambda x : dict_provincia[x] if x in dict_provincia else x)
df2 = df2[df2['Provincia'] != df2[df2.columns[-1]]]
df2 = df2.reset_index(drop=True)
df2 = df2.drop_duplicates(subset="Provincia", keep="first")

df2.head(70)
# Out:
#                  Provincia  Número de declaraciones  Renta bruta media  \
# 0                  Almería                   324413              21399
# 1                    Cádiz                   495879              24497
# 2                  Córdoba                   351445              21879
# 3                  Granada                   403795              23515
# 4                   Huelva                   239196              20972
# 5                     Jaén                   299266              20266
# 6                   Málaga                   696664              24712
# 7                  Sevilla                   832025              25321
# 8                   Huesca                   114378              25513
# 9                   Teruel                    69808              23356
# 10                Zaragoza                   524938              27827
# 11                Asturias                   518251              27448
# ...

# %%
url3 = "https://sede.agenciatributaria.gob.es/AEAT/Contenidos_Comunes/La_Agencia_Tributaria/Estadisticas/Publicaciones/sites/irpfmunicipios/2014/jrubik46d57f66ff15f8ce6709405779df56d2f7e359c5.html"

response = requests.get(url3)
response.encoding = 'utf-8'  
soup = BeautifulSoup(response.text, 'html.parser')

tables = soup.find_all('table')

df3 = pd.read_html(str(tables[0]), decimal=",", thousands=".")[0]
df3 = df3.rename(columns={"Unnamed: 0": "Provincia"})
periodo = 2014
df3['Año'] = periodo

df3.to_csv("datos_irpf_provincia_2014.csv", index=False)

print(df3.shape)
df3.head(70)
# Out:
# (68, 11)
# C:\Users\Jon\AppData\Local\Temp\ipykernel_21880\1674490486.py:9: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df3 = pd.read_html(str(tables[0]), decimal=",", thousands=".")[0]
#         Provincia  Número de declaraciones  Renta bruta media  \
# 0           Total                 19359020              24568
# 1       Andalucía                  3243402              20707
# 2         Almería                   271612              18666
# 3           Cádiz                   442255              21760
# 4         Córdoba                   332680              19111
# ..            ...                      ...                ...
# 63          Ceuta                    27949              30026
# 64        Melilla                    27418              28712
# 65        Melilla                    27418              28712
# ...

# %%
dict_provincia = {
    "Araba/Álava": 1, "Albacete": 2, "Alicante/Alacant": 3, "Almería": 4, "Ávila": 5,
    "Badajoz": 6, "Balears, Illes": 7, "Barcelona": 8, "Burgos": 9, "Cáceres": 10,
    "Cádiz": 11, "Castellón/Castelló": 12, "Ciudad Real": 13, "Córdoba": 14,
    "Coruña, A": 15, "Cuenca": 16, "Girona": 17, "Granada": 18, "Guadalajara": 19,
    "Gipuzkoa": 20, "Huelva": 21, "Huesca": 22, "Jaén": 23, "León": 24, "Lleida": 25,
    "Rioja, La": 26, "Lugo": 27, "Madrid": 28, "Málaga": 29, "Murcia": 30, "Navarra": 31,
    "Ourense": 32, "Asturias": 33, "Palencia": 34, "Palmas, Las": 35, "Pontevedra": 36,
    "Salamanca": 37, "Santa Cruz de Tenerife": 38, "Cantabria": 39, "Segovia": 40,
    "Sevilla": 41, "Soria": 42, "Tarragona": 43, "Teruel": 44, "Toledo": 45,
    "Valencia/València": 46, "Valladolid": 47, "Bizkaia": 48, "Zamora": 49,
    "Zaragoza": 50, "Ceuta": 51, "Melilla": 52
}

df3['id_provincia'] = df3['Provincia'].apply(lambda x : dict_provincia[x] if x in dict_provincia else x)
df3 = df3[df3['Provincia'] != df3[df3.columns[-1]]]
df3 = df3.reset_index(drop=True)
df3 = df3.drop_duplicates(subset="Provincia", keep="first")

df3.head(70)
# Out:
#                  Provincia  Número de declaraciones  Renta bruta media  \
# 0                  Almería                   271612              18666
# 1                    Cádiz                   442255              21760
# 2                  Córdoba                   332680              19111
# 3                  Granada                   369563              20646
# 4                   Huelva                   207008              19051
# 5                     Jaén                   284036              17693
# 6                   Málaga                   592183              21409
# 7                  Sevilla                   744065              22624
# 8                   Huesca                   110777              22385
# 9                   Teruel                    69817              20904
# 10                Zaragoza                   502642              24806
# 11                Asturias                   511584              24819
# ...

# %%
# Concatenar verticalmente los dos DataFrames
df_concat = pd.concat([df2, df3], ignore_index=True)

# Guardar el resultado en un nuevo archivo si lo deseas
df_concat.to_csv("RENTA.csv", index=False)

# Verificar resultado
print(df_concat.shape)
print(df_concat['Año'].value_counts())
df_concat.head(94)
# Out:
# (94, 12)
# Año
# 2019    47
# 2014    47
# Name: count, dtype: int64
#              Provincia  Número de declaraciones  Renta bruta media  \
# 0              Almería                   324413              21399
# 1                Cádiz                   495879              24497
# 2              Córdoba                   351445              21879
# 3              Granada                   403795              23515
# 4               Huelva                   239196              20972
# ..                 ...                      ...                ...
# 89    Alicante/Alacant                   710954              20454
# 90  Castellón/Castelló                   271357              21605
# 91   Valencia/València                  1159927              23100
# 92               Ceuta                    27949              30026
# 93             Melilla                    27418              28712
#
#     Número de municipios  Rentas  del trabajo  Rentas exentas  Renta bruta  \
# ...
