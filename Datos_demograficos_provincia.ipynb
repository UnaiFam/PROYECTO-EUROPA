# %%
import pandas as pd

ruta_archivo = "Fuentes de datos demograficos/2852.csv"

# Carga el archivo con los parámetros correctos
df = pd.read_csv(ruta_archivo, sep=';', encoding='latin1', decimal=',')

# Guarda como nuevo CSV (con coma como separador por defecto)
df.to_csv("datos_irpf_provincia_limpio.csv", index=False)

# Imprime información
print(df.shape)
df.head(50)
# Out:
# (318, 4)
#              Provincias   Sexo  Periodo       Total
# 0                 Total  Total     2021  47.385.107
# 1                 Total  Total     2020  47.450.795
# 2                 Total  Total     2019  47.026.208
# 3                 Total  Total     2018  46.722.980
# 4                 Total  Total     2017  46.572.132
# 5                 Total  Total     2016  46.557.008
# 6           02 Albacete  Total     2021     386.464
# 7           02 Albacete  Total     2020     388.270
# 8           02 Albacete  Total     2019     388.167
# 9           02 Albacete  Total     2018     388.786
# 10          02 Albacete  Total     2017     390.032
# 11          02 Albacete  Total     2016     392.118
# 12  03 Alicante/Alacant  Total     2021   1.881.762
# 13  03 Alicante/Alacant  Total     2020   1.879.888
# 14  03 Alicante/Alacant  Total     2019   1.858.683
# 15  03 Alicante/Alacant  Total     2018   1.838.819
# 16  03 Alicante/Alacant  Total     2017   1.825.332
# ...
