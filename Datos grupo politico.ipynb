# %%
import pandas as pd

ruta_archivo = "Fuentes de datos demograficos/resultado_europeas_puntoycoma.csv"

# Carga el archivo con los parámetros correctos
df = pd.read_csv(ruta_archivo, sep=';', encoding='latin1', decimal=',')

# Guarda como nuevo CSV (con coma como separador por defecto)
df.to_csv("datos_procentajepartido_2024.csv", index=False)

# Imprime información
print(df.shape)
df.head(50)
# Out:
# (11, 2)
#                                       Partido Porcentaje de votos
# 0                        PP - Partido Popular               34.21
# 1   PSOE - Partido Socialista Obrero EspaÃ±ol               30.19
# 2                                   Vox - Vox                9.63
# 3                           Ahora RepÃºblicas                4.91
# 4                                       Sumar                4.67
# 5                  SALF - Se AcabÃ³ la Fiesta                4.58
# 6                           Podemos - Podemos                 3.3
# 7                                    Junts UE                2.52
# 8                                        CEUS                1.63
# 9                   Otros partidos polÃ­ticos                4.36
# 10                                      Total               100.0

# %%
ruta_archivo = "Fuentes de datos demograficos/Escaños por grupo politico-corr.csv"

# Carga el archivo con los parámetros correctos
df1 = pd.read_csv(ruta_archivo, sep=';', encoding='latin1', decimal=',')

# Guarda como nuevo CSV (con coma como separador por defecto)
df1.to_csv("datos_grupo_politico_2024.csv", index=False)

# Imprime información
print(df.shape)
df1.head(50)
# Out:
# (11, 2)
#              Grupos politicos del Parlamento Europeo  Numero de escaños
# 0                            Partido Popular Europeo                 22
# 1  Grupo de Alianza Progresita de Socialistas y D...                 20
# 2                                Patriots for Europe                  6
# 3                                       Renew Europe                  1
# 4                                Grupo de los Verdes                  4
# 5                                           The Left                  4
# 6                                                 NI                  4
